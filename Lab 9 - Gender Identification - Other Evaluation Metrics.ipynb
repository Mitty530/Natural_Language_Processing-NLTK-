# %% [markdown]
# ## Gender Identification - Other Evaluation Metrics (Precision and Recall)

# %%
# Import the relevant packages
import nltk
from nltk.corpus import names
import random

# %%
def gender_features(word):
    return {'suffix1': word[-1:],
            'suffix2': word[-2:]}

gender_features("Mafas")
# Out:
# {'suffix1': 's', 'suffix2': 'as'}

# %%
# Generate names
labeled_names = ([(name, 'male') for name in names.words('male.txt')] +
[(name, 'female') for name in names.words('female.txt')])

random.shuffle(labeled_names)

# %%
# Data Split
train_names = labeled_names[1500:]
devtest_names = labeled_names[500:1500]
test_names = labeled_names[:500]

train_set = [(gender_features(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
test_set = [(gender_features(n), gender) for (n, gender) in test_names]

# %%
# Build the model
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print("\nThe validation accuracy is: ", nltk.classify.accuracy(classifier, devtest_set)*100,"%")
print("\nThe testing accuracy is: ", nltk.classify.accuracy(classifier, test_set)*100,"%")
# Out:
# The validation accuracy is:  78.4 %
#
# The testing accuracy is:  78.8 %

# %%
# Form Classification Report
errors = []
prediction_list = []
TP=0
TN=0
FP=0
FN=0
for (name, tag) in devtest_names:
    guess = classifier.classify(gender_features(name))
    prediction_list.append((tag, guess, name))
    if guess == 'male':
        if tag == 'male':
            TP+=1
        else:
            FP+=1
    else:
        if tag == 'female':
            TN+=1
        else:
            FN+=1       
  
    if guess != tag:
        errors.append((tag, guess, name))

print('\nTotal number of test items: ',len(prediction_list))
print('Total number of errors: ', len(errors))
# Out:
# Total number of test items:  1000
# Total number of errors:  216

# %%
print("\n~~~~~~ Classification ~~~~~~" )
print('TP: ', TP)
print('FP: ', FP)
print('TN: ', TN)
print('FN: ', FN)
# Out:
# ~~~~~~ Classification ~~~~~~
# TP:  263
# FP:  107
# TN:  521
# FN:  109

# %%
# Confusion Matrix
def column(matrix, i):
    return [row[i] for row in matrix]

print("\n~~~~~~ Confusion Matrix ~~~~~~")
cm = nltk.ConfusionMatrix(column(prediction_list,0), column(prediction_list,1))
print(cm.pretty_format(sort_by_count=True, show_percents=True, truncate=9))
# Out:
# ~~~~~~ Confusion Matrix ~~~~~~
#        |      f        |
#        |      e        |
#        |      m      m |
#        |      a      a |
#        |      l      l |
#        |      e      e |
# -------+---------------+
# female | <52.1%> 10.7% |
#   male |  10.9% <26.3%>|
# -------+---------------+
# (row = reference; col = test)

# %% [markdown]
# ## Choosing the Right Features and Accuracy

# %%
import nltk

def gender_features2(name):
    features = {}
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())
    return features

gender_features2('John')
# Out:
# {'first_letter': 'j',
#  'last_letter': 'n',
#  'count(a)': 0,
#  'has(a)': False,
#  'count(b)': 0,
#  'has(b)': False,
#  'count(c)': 0,
#  'has(c)': False,
#  'count(d)': 0,
#  'has(d)': False,
#  'count(e)': 0,
#  'has(e)': False,
#  'count(f)': 0,
#  'has(f)': False,
#  'count(g)': 0,
#  'has(g)': False,
#  'count(h)': 1,
#  'has(h)': True,
#  'count(i)': 0,
#  'has(i)': False,
#  'count(j)': 1,
#  'has(j)': True,
#  'count(k)': 0,
#  'has(k)': False,
#  'count(l)': 0,
#  'has(l)': False,
#  'count(m)': 0,
#  'has(m)': False,
#  'count(n)': 1,
#  'has(n)': True,
#  'count(o)': 1,
#  'has(o)': True,
#  'count(p)': 0,
#  'has(p)': False,
#  'count(q)': 0,
#  'has(q)': False,
#  'count(r)': 0,
#  'has(r)': False,
#  'count(s)': 0,
#  'has(s)': False,
#  'count(t)': 0,
#  'has(t)': False,
#  'count(u)': 0,
#  'has(u)': False,
#  'count(v)': 0,
#  'has(v)': False,
#  'count(w)': 0,
#  'has(w)': False,
#  'count(x)': 0,
#  'has(x)': False,
#  'count(y)': 0,
#  'has(y)': False,
#  'count(z)': 0,
#  'has(z)': False}

# %%
from nltk.corpus import names
labeled_names = ([(name, 'male') for name in names.words('male.txt')] +
[(name, 'female') for name in names.words('female.txt')])

import random
random.shuffle(labeled_names)
print(labeled_names)
# Out:
# [('Emmalynn', 'female'), ('Bellanca', 'female'), ('Alexina', 'female'), ('Mozelle', 'female'), ('Jonathan', 'male'), ('Pamela', 'female'), ('Viviene', 'female'), ('Kaylyn', 'female'), ('Rora', 'female'), ('Cissie', 'female'), ('Mischa', 'male'), ('Eileen', 'female'), ('Correy', 'female'), ('Roddy', 'male'), ('Rick', 'male'), ('Nicholas', 'male'), ('Ailyn', 'female'), ('Lev', 'male'), ('Cindie', 'female'), ('Sigrid', 'female'), ('Axel', 'male'), ('Briney', 'female'), ('Ernaline', 'female'), ('Antonetta', 'female'), ('Carlisle', 'female'), ('Brandy', 'male'), ('Ibrahim', 'male'), ('Harriott', 'female'), ('Tiffie', 'female'), ('Eddy', 'female'), ('Barnabas', 'male'), ('Gretel', 'female'), ('Magna', 'female'), ('Rosabelle', 'female'), ('Alan', 'male'), ('Dylan', 'male'), ('Maurie', 'male'), ('Giancarlo', 'male'), ('Amaleta', 'female'), ('Gabriell', 'male'), ('Prudy', 'female'), ('Lucretia', 'female'), ('Violette', 'female'), ('Beilul', 'female'), ('Hunt', 'male'), ('Jessamyn', 'female'), ('Redmond', 'male'), ('Anselma', 'female'), ('Meyer', 'male'), ('Crystal', 'female'), ('Saunder', 'male'), ('Edna', 'female'), ('Pearla', 'female'), ('Edgardo', 'male'), ('Wilona', 'female'), ('Devin', 'female'), ('Christiana', 'female'), ('Elisha', 'female'), ('Renata', 'female'), ('Fionnula', 'female'), ('Butler', 'male'), ('Olle', 'male'), ('Horatio', 'male'), ('Odilia', 'female'), ('Roosevelt', 'male'), ('Trevor', 'male'), ('Jerry', 'female'), ('Raquel', 'female'), ('Joceline', 'female'), ('Gunilla', 'female'), ('Roxi', 'female'), ('Nananne', 'female'), ('Lex', 'male'), ('Jessalin', 'female'), ('Lolly', 'female'), ('Melissa', 'female'), ('Kaia', 'female'), ('Walton', 'male'), ('Olin', 'male'), ('Zak', 'male'), ('Nancy', 'female'), ('Sean', 'male'), ('Tim', 'female'), ('Monroe', 'male'), ('Jorey', 'female'), ('Conny', 'female'), ('Anastassia', 'female'), ('Nalani', 'female'), ('Karin', 'female'), ('Michaeline', 'female'), ('Leigh', 'female'), ('Anissa', 'female'), ('Pauline', 'female'), ('Laetitia', 'female'), ('Addie', 'male'), ('Marty', 'male'), ('Shelden', 'male'), ('Tara', 'female'), ('Alfreda', 'female'), ('Lane', 'male'), ('Salvador', 'male'), ('Perry', 'male'), ('Carson', 'male'), ('Kizzee', 'female'), ('Michel', 'female'), ('Maurise', 'female'), ('Loralie', 'female'), ('Indira', 'female'), ('Chen', 'male'), ('Coleman', 'male'), ('Danyelle', 'female'), ('Steward', 'male'), ('Theodosia', 'female'), ('Sissy', 'female'), ('Jocelyne', 'female'), ('Sherwood', 'male'), ('Judson', 'male'), ('Norina', 'female'), ('Brad', 'male'), ('Ferdie', 'male'), ('Eleanore', 'female'), ('Pennie', 'female'), ('Aldus', 'male'), ('Georgina', 'female'), ('Fanni', 'female'), ('Gus', 'female'), ('Lorenzo', 'male'), ('Darline', 'female'), ('Amber', 'female'), ('Mersey', 'female'), ('Christiano', 'male'), ('Angelia', 'female'), ('Starlin', 'female'), ('Brigida', 'female'), ('Jewel', 'female'), ('Novelia', 'female'), ('Stanford', 'male'), ('Trixy', 'female'), ('Zelda', 'female'), ('Chas', 'male'), ('Rea', 'female'), ('Danika', 'female'), ('Waylan', 'male'), ('Jobina', 'female'), ('Krystal', 'female'), ('Aindrea', 'female'), ('Lucio', 'male'), ('Coriss', 'female'), ('Kaleena', 'female'), ('Reiko', 'female'), ('Christiane', 'female'), ('Dean', 'male'), ('Nicolas', 'male'), ('Katrinka', 'female'), ('Galina', 'female'), ('Dyann', 'female'), ('Ignacius', 'male'), ('Natassia', 'female'), ('Logan', 'male'), ('Nathanial', 'male'), ('Albrecht', 'male'), ('Lorita', 'female'), ('Wendi', 'female'), ('Erny', 'male'), ('Laraine', 'female'), ('Helise', 'female'), ('Faydra', 'female'), ('Erastus', 'male'), ('Zachery', 'male'), ('Frayda', 'female'), ('Clare', 'female'), ('Tove', 'female'), ('Rozalin', 'female'), ('Theodoric', 'male'), ('Nadine', 'female'), ('Dulcie', 'female'), ('Hendrick', 'male'), ('Ikey', 'male'), ('Brent', 'male'), ('Ulick', 'male'), ('Leonid', 'male'), ('Devi', 'female'), ('Johnathon', 'male'), ('Gratiana', 'female'), ('Atlanta', 'female'), ('Emilio', 'male'), ( ...

# %%
featuresets = [(gender_features2(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)
print("The accuracy is: ", nltk.classify.accuracy(classifier, test_set))
# Out:
# The accuracy is:  0.766

# %%
train_names = labeled_names[1500:]
devtest_names = labeled_names[500:1500]
test_names = labeled_names[:500]


train_set = [(gender_features2(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features2(n), gender) for (n, gender) in devtest_names]
test_set = [(gender_features2(n), gender) for (n, gender) in test_names]

# %%
print("The validation accuracy is: ", nltk.classify.accuracy(classifier, devtest_set))
# Out:
# The validation accuracy is:  0.767

# %%
errors = []
for (name, tag) in devtest_names:
    guess = classifier.classify(gender_features2(name))
    if guess != tag:
        errors.append((tag, guess, name))
for (tag, guess, name) in sorted(errors):
    print('correct={:<8} guess={:<8s} name={:<30}'.format(tag, guess, name))
# Out:
# correct=female   guess=male     name=Addis
# correct=female   guess=male     name=Audy
# correct=female   guess=male     name=Avrit
# correct=female   guess=male     name=Berny
# correct=female   guess=male     name=Betsy
# correct=female   guess=male     name=Beverly
# correct=female   guess=male     name=Blondy
# correct=female   guess=male     name=Brooke
# correct=female   guess=male     name=Brunhilde
# correct=female   guess=male     name=Cameo
# correct=female   guess=male     name=Chad
# correct=female   guess=male     name=Chrystal
# correct=female   guess=male     name=Chrystel
# correct=female   guess=male     name=Con
# correct=female   guess=male     name=Corey
# correct=female   guess=male     name=Cortney
# correct=female   guess=male     name=Cyb
# correct=female   guess=male     name=Daffy
# correct=female   guess=male     name=Dagmar
# correct=female   guess=male     name=Darb
# correct=female   guess=male     name=Deborah
# correct=female   guess=male     name=Dode
# correct=female   guess=male     name=Doll
# correct=female   guess=male     name=Dolly
# correct=female   guess=male     name=Doloritas
# correct=female   guess=male     name=Dorcas
# correct=female   guess=male     name=Dorise
# correct=female   guess=male     name=Dorothee
# correct=female   guess=male     name=Eryn
# correct=female   guess=male     name=Felicdad
# correct=female   guess=male     name=Fern
# correct=female   guess=male     name=Fiorenze
# correct=female   guess=male     name=Fleurette
# correct=female   guess=male     name=Flore
# correct=female   guess=male     name=Florette
# correct=female   guess=male     name=Floris
# correct=female   guess=male     name=Flory
# correct=female   guess=male     name=Flower
# correct=female   guess=male     name=Franky
# correct=female   guess=male     name=Fred
# correct=female   guess=male     name=Freddi
# correct=female   guess=male     name=Gates
# correct=female   guess=male     name=Georgette
# correct=female   guess=male     name=Glory
# correct=female   guess=male     name=Greer
# correct=female   guess=male     name=Grethel
# correct=female   guess=male     name=Gussie
# correct=female   guess=male     name=Gussy
# correct=female   guess=male     name=Gwen
# correct=female   guess=male     name=Gwendolin
# correct=female   guess=male     name=Gwenni
# correct=female   guess=male     name=Gwyn
# correct=female   guess=male     name=Happy
# correct=female   guess=male     name=Heath
# correct=female   guess=male     name=Honey
# correct=female   guess=male     name=Ingrid
# correct=female   guess=male     name=Janot
# correct=female   guess=male     name=Josy
# correct=female   guess=male     name=Judith
# correct=female   guess=male     name=Justin
# correct=female   guess=male     name=Kameko
# correct=female   guess=male     name=Kit
# correct=female   guess=male     name=Meg
# correct=female   guess=male     name=Mikako
# correct=female   guess=male     name=Myriam
# correct=female   guess=male     name=Noreen
# correct=female   guess=male     name=Odette
# correct=female   guess=male     name=Page
# correct=female   guess=male     name=Pansy
# correct=female   guess=male     name=Pegeen
# correct=female   guess=male     name=Pen
# correct=female   guess=male     name=Perry
# correct=female   guess=male     name=Piper
# correct=female   guess=male     name=Quinn
# correct=female   guess=male     name=Remy
# correct=female   guess=male     name=Robby
# correct=female   guess=male     name=Roby
# correct=female   guess=male     name=Rodi
# correct=female   guess=male     name=Rodie
# correct=female   guess=male     name=Rory
# correct=female   guess=male     name=Rosalynd
# correct=female   guess=male     name=Rosemary
# correct=female   guess=male     name=Rosette
# correct=female   guess=male     name=Roshelle
# correct=female   guess=male     name=Rosie
# correct=female   guess=male     name=Roslyn
# correct=female   guess=male     name=Row
# correct=female   guess=male     name=Roz
# correct=female   guess=male     name=Roze
# correct=female   guess=male     name=Ruthe
# correct=female   guess=male     name=Sarah
# correct=female   guess=male     name=Sharon
# correct=female   guess=male     name=Sharron
# correct=female   guess=male     name=Shell
# correct=female   guess=male     name=Sher
# correct=female   guess=male     name=Sherill
# correct=female   guess=male     name=Suellen
# correct=female   guess=male     name=Sunny
# correct=female   guess=male     name=Suzzy
# correct=female   guess=male     name=Tammy
# correct=female   guess=male     name=Teddy
# correct=female   guess=male     name=Terri-Jo
# correct=female   guess=male     name=Theo
# correct=female   guess=male     name=Tommi
# correct=female   guess=male     name=Tori
# correct=female   guess=male     name=Trudie
# correct=female   guess=male     name=Violet
# correct=female   guess=male     name=Wendie
# correct=female   guess=male     name=Wenonah
# correct=female   guess=male     name=Wilie
# correct=female   guess=male     name=Windy
# correct=female   guess=male     name=Winonah
# correct=female   guess=male     name=Yehudit
# correct=female   guess=male     name=Yoko
# correct=male     guess=female   name=Ajay
# correct=male     guess=female   name=Alaa
# correct=male     guess=female   name=Alastair
# correct=male     guess=female   name=Alexis
# correct=male     guess=female   name=Alister
# correct=male     guess=female   name=Allah
# correct=male     guess=female   name=Alley
# correct=male     guess=female   name=Ambrosi
# correct=male     guess=female   name=Anatol
# correct=male     guess=female   name=Andre
# correct=male     guess=female   name=Ansel
# correct=male     guess=female   name=Antoine
# correct=male     guess=female   name=Arel
# correct=male     guess=female   name=Augustine
# correct=male     guess=female   name=Bartolomei
# correct=male     guess=female   name=Benjamin
# correct=male     guess=female   name=Bentley
# correct=male     guess=female   name=Berkie
# correct=male     guess=female   name=Carl
# correct=male     guess=female   name=Carlton
# correct=male     guess=female   name=Chaddie
# correct=male     guess=female   name=Chancey
# correct=male     guess=female   name=Charley
# correct=male     guess=female   name=Clancy
# correct=male     guess=female   name=Clay
# correct=male     guess=female   name=Clint
# correct=male     guess=female   name=Clinten
# correct=male     guess=female   name=Damian
# correct=male     guess=female   name=Daniel
# correct=male     guess=female   name=Dannie
# correct=male     guess=female   name=Darrel
# correct=male     guess=female   name=Davide
# correct=male     guess=female   name=Dorian
# correct=male     guess=female   name=Drake
# correct=male     guess=female   name=Duane
# correct=male     guess=female   name=Elijah
# correct=male     guess=female   name=Elnar
# correct=male     guess=female   name=Emil
# correct=male     guess=female   name=Emile
# correct=male     guess=female   name=Esme
# correct=male     guess=female   name=Felice
# correct=male     guess=female   name=Felipe
# correct=male     guess=female   name=Gavriel
# correct=male     guess=female   name=Gay
# correct=male     guess=female   name=Gerri
# correct=male     guess=female   name=Gill
# correct=male     guess=female   name=Grace
# correct=male     guess=female   name=Hamel
# correct=male     guess=female   name=Hamlen
# correct=male     guess=female   name=Henrie
# correct=male     guess=female   name=Ingamar
# correct=male     guess=female   name=Isadore
# correct=male     guess=female   name=Jae
# correct=male     guess=female   name=Jaime
# correct=male     guess=female   name=Jean-Paul
# correct=male     guess=female   name=Jedediah
# correct=male     guess=female   name=Jeremiah
# correct=male     guess=female   name=Jermaine
# correct=male     guess=female   name=Jerome
# correct=male     guess=female   name=Karsten
# correct=male     guess=female   name=Kelsey
# correct=male     guess=female   name=Kevan
# correct=male     guess=female   name=Lance
# correct=male     guess=female   name=Larry
# correct=male     guess=female   name=Lauren
# correct=male     guess=female   name=Leigh
# correct=male     guess=female   name=Lind
# correct=male     guess=female   name=Lorrie
# correct=male     guess=female   name=Lucian
# correct=male     guess=female   name=Mace
# correct=male     guess=female   name=Marietta
# correct=male     guess=female   name=Marlon
# correct=male     guess=female   name=Marvin
# correct=male     guess=female   name=Mattie
# correct=male     guess=female   name=Maximilien
# correct=male     guess=female   name=Melvyn
# correct=male     guess=female   name=Mendie
# correct=male     guess=female   name=Merle
# correct=male     guess=female   name=Milt
# correct=male     guess=female   name=Morrie
# correct=male     guess=female   name=Nathanael
# correct=male     guess=female   name=Nealy
# correct=male     guess=female   name=Nickey
# correct=male     guess=female   name=Niles
# correct=male     guess=female   name=Orville
# correct=male     guess=female   name=Pascal
# correct=male     guess=female   name=Pearce
# correct=male     guess=female   name=Prince
# correct=male     guess=female   name=Rabbi
# correct=male     guess=female   name=Randall
# correct=male     guess=female   name=Randi
# correct=male     guess=female   name=Reilly
# correct=male     guess=female   name=Richie
# correct=male     guess=female   name=Ritchie
# correct=male     guess=female   name=Salvatore
# correct=male     guess=female   name=Sandy
# correct=male     guess=female   name=Scotti
# correct=male     guess=female   name=Scottie
# correct=male     guess=female   name=Shelley
# correct=male     guess=female   name=Si
# correct=male     guess=female   name=Silvain
# correct=male     guess=female   name=Skelly
# correct=male     guess=female   name=Slade
# correct=male     guess=female   name=Stanleigh
# correct=male     guess=female   name=Stinky
# correct=male     guess=female   name=Tammie
# correct=male     guess=female   name=Tanney
# correct=male     guess=female   name=Terence
# correct=male     guess=female   name=Terrance
# correct=male     guess=female   name=Val
# correct=male     guess=female   name=Vance
# correct=male     guess=female   name=Vasily
# correct=male     guess=female   name=Vin
# correct=male     guess=female   name=Virge
# correct=male     guess=female   name=Vite
# correct=male     guess=female   name=Yancy
# correct=male     guess=female   name=Yardley
# correct=male     guess=female   name=Zalman
# correct=male     guess=female   name=Zechariah
